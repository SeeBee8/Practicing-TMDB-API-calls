# %% [markdown]
# # Practicing TMDB API Calls
#
# *Christina Brockway*

# %% [markdown]
# ## Imports

# %%
#Import packages
import os, time, json
import tmdbsimple as tmdb
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm_notebook

# %% [markdown]
# ## Create Folder

# %%
#Create the folder for saving files
FOLDER = 'MovieData/'
os.makedirs(FOLDER, exist_ok = True)
os.listdir (FOLDER)
# Out:
# ['.ipynb_checkpoints',
#  'basics-filter.csv',
#  'ratings-filter.csv',
#  'tmdb_api_results 2010.json']

# %% [markdown]
# ## Load API Key

# %%
with open('/Users/csbro/.secret/tmdb_api.json', 'r') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['api_key'])

# %%
tmdb.API_KEY = login['api_key']

# %% [markdown]
# ## Define Functions

# %%
def get_movie_with_rating(movie_id):
    #Get movie object using movie_id
    movie= tmdb.Movies(movie_id)
    #Save the dictionaries 
    movie_info = movie.info()
    releases = movie.releases()
    #Loop through countries for only US
    for c in releases['countries']:
        if c['iso_3166_1'] == 'US':
            movie_info['certification']= c['certification']
    return movie_info

# %%
def write_json(new_data, filename):
    """Appends a list of records (new_data) into a json file (filename).
    Adapted from: https://www.geeksforgeeks.org/append-to-json-file-using-python/"""

    with open(filename, 'r+') as file:
        #Load existing data into dictionary
        file_data = json.load(file)
        #choose to extend or append
        if (type(new_data) == list) & (type(file_data) == list):
            file_data.extend(new_data)
        else:
            file_data.append(new_data)
        #set file's current position at offset
        file.seek(0)
        #convert back to json
        json.dump(file_data, file)

# %% [markdown]
# ## Confirm API Function works

# %%
test= ["tt0848228", "tt0332280"]
results= []
for movie_id in test:
    movie_info = get_movie_with_rating(movie_id)
    results.append(movie_info)
pd.DataFrame(results)
# Out:
#    adult                     backdrop_path  \
# 0  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg
# 1  False  /qom1SZSENdmHFNZBXbtJAU0WTlC.jpg
#
#                                belongs_to_collection     budget  \
# 0  {'id': 86311, 'name': 'The Avengers Collection...  220000000
# 1                                               None   29000000
#
#                                               genres  \
# 0  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
#
#                                             homepage     id    imdb_id  \
# 0         https://www.marvel.com/movies/the-avengers  24428  tt0848228
# 1  http://www.newline.com/properties/notebookthe....  11036  tt0332280
#
#   original_language original_title  ...     revenue  runtime  \
# 0                en   The Avengers  ...  1518815515      143
# 1                en   The Notebook  ...   115603229      123
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                      tagline         title  video  \
# 0                    Some assembly required.  The Avengers  False
# 1  Behind every great love is a great story.  The Notebook  False
#
#    vote_average vote_count certification
# 0          7.71      29274         PG-13
# 1          7.88      10688         PG-13
#
# [2 rows x 26 columns]

# %% [markdown]
# ## Load in data

# %%
basics = pd.read_csv("MovieData/basics-filter.csv")

basics
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# 3      tt0088751     movie                                  The Naked Monster
# 4      tt0096056     movie                               Crime and Punishment
# ...          ...       ...                                                ...
# 86974  tt9914942     movie                             Life Without Sara Amat
# 86975  tt9915872     movie                               The Last White Witch
# 86976  tt9916170     movie                                      The Rehearsal
# 86977  tt9916190     movie                                          Safeguard
# 86978  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0     2001.0      NaN
# 1      El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                     The Other Side of the Wind        0     2018.0      NaN
# 3                              The Naked Monster        0     2005.0      NaN
# 4                           Crime and Punishment        0     2002.0      NaN
# ...                                          ...      ...        ...      ...
# 86974                 La vida sense la Sara Amat        0     2019.0      NaN
# 86975                  My Girlfriend is a Wizard        0     2019.0      NaN
# 86976                                   O Ensaio        0     2019.0      NaN
# 86977                                  Safeguard        0     2020.0      NaN
# 86978                                   Akelarre        0     2020.0      NaN
#
#        runtimeMinutes                     genres
# 0                 118     Comedy,Fantasy,Romance
# 1                  70                      Drama
# 2                 122                      Drama
# 3                 100       Comedy,Horror,Sci-Fi
# 4                 126                      Drama
# ...               ...                        ...
# 86974              74                      Drama
# 86975              97       Comedy,Drama,Fantasy
# 86976              51                      Drama
# 86977              95  Action,Adventure,Thriller
# 86978              92              Drama,History
#
# [86979 rows x 9 columns]

# %% [markdown]
# ## Define variables

# %%
#Set the Year to filter for
YEAR = 2010
#Create an empty list for errors
errors = []

# %%
#Prepare DF for json file
JSON_MOVIE= f'{FOLDER}tmdb_api_results {YEAR}.json'

#Check if file exists
file_exists = os.path.isfile(JSON_MOVIE)
if file_exists == False:
    print(f'Creating json file for API results for {YEAR}')
    with open(JSON_MOVIE, 'w') as f:
        json.dump([{'imdb_id':0}], f)
else: 
    print(f'{JSON_MOVIE} already exists.')
# Out:
# MovieData/tmdb_api_results 2010.json already exists.

# %%
#Saving 2010  as the current df
df = basics.loc[basics['startYear'] == YEAR].copy()
#saving movie_id to separate variable
movie_ids = df['tconst']

# %%
#Load exisiting data from json into DF called previous_df
previous_df = pd.read_json(JSON_MOVIE)

# %%
#filter out any ids that are already in the file
needed_mids = movie_ids[~movie_ids.isin(previous_df['imdb_id'])]

# %%
# Loop through movie_ids with a progress bar
for movie_id in tqdm_notebook(needed_mids, f'Movies from {YEAR}'):
    # Get index and movie id from the list:
    try:
        temp = get_movie_with_rating(movie_id)
        write_json(temp, JSON_MOVIE)
        time.sleep(0.02)
    except Exception as e:
        errors.append([movie_id, e])

print(f' - Total Errors: {len(errors)}')
# Out:
# Movies from 2010:   0%|          | 0/3862 [00:00<?, ?it/s]
#  - Total Errors: 1126

# %%
print(errors)
# Out:
# [['tt0230212', HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0230212?api_key=35a7b33196852a5816731c8b4196d66c')], ['tt0464032', HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0464032?api_key=35a7b33196852a5816731c8b4196d66c')], ['tt0465637', HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0465637?api_key=35a7b33196852a5816731c8b4196d66c')], ['tt0465760', HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0465760?api_key=35a7b33196852a5816731c8b4196d66c')], ['tt0473343', HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0473343?api_key=35a7b33196852a5816731c8b4196d66c')], ['tt0483839', HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0483839?api_key=35a7b33196852a5816731c8b4196d66c')], ['tt0490199', HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0490199?api_key=35a7b33196852a5816731c8b4196d66c')], ['tt0765485', HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0765485?api_key=35a7b33196852a5816731c8b4196d66c')], ['tt0800054', HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0800054?api_key=35a7b33196852a5816731c8b4196d66c')], ['tt0800092', HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0800092?api_key=35a7b33196852a5816731c8b4196d66c')], ['tt0907731', HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0907731?api_key=35a7b33196852a5816731c8b4196d66c')], ['tt0910926', HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0910926?api_key=35a7b33196852a5816731c8b4196d66c')], ['tt0960827', HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0960827?api_key=35a7b33196852a5816731c8b4196d66c')], ['tt0977639', HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0977639?api_key=35a7b33196852a5816731c8b4196d66c')], ['tt1008015', HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1008015?api_key=35a7b33196852a5816731c8b4196d66c')], ['tt1008046', HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1008046?api_key=35a7b33196852a5816731c8b4196d66c')], ['tt1020011', HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1020011?api_key=35a7b33196852a5816731c8b4196d66c')], ['tt1022884', HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1022884?api_key=35a7b33196852a5816731c8b4196d66c')], ['tt10265862', HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt10265862?api_key=35a7b33196852a5816731c8b4196d66c')], ['tt10417654', HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt10417654?api_key=35a7b33196852a5816731c8b4196d66c')], ['tt1047439', HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1047439?api_key=35a7b33196852a5816731c8b4196d66c')], ['tt10500904', HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt10500904?api_key=35a7b33196852a5816731c8b4196d66c')], ['tt1103269', HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1103269?api_key=35a7b33196852a5816731c8b4196d66c')], ['tt1107855', HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1107855?api_key=35a7b33196852a5816731c8b4196d66c')], ['tt1111884', HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt1111884?api_key=35a7b33196852a5816731c8b4196d66c')], ['tt11154898', HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt11154898?api_key=35a7b33196852a5816731c8b4196d66c')], ['tt11198656', HTTPError('404 Client Er ...

# %%
final_2010_df = pd.read_json(JSON_MOVIE)
final_2010_df.to_csv (f'{FOLDER}final_tmdb_data_{YEAR}.csv.gz',
                      compression = 'gzip', index = False)
